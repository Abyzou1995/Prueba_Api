# %% [markdown]
# ETL- INDIVIDUAL PROJECT - HENRY MLOPS

# %% [markdown]
# Import Needed Libraries for this project

# %%
import pandas as pd
import numpy as np
import json
import ast

# %% [markdown]
# After fixing dataset structure , next step is to load the dataset

# %%
df=pd.read_csv("Dataset_original/movies_dataset_arreglado_1.csv",delimiter=";")
# Out:
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\4213308071.py:1: DtypeWarning: Columns (10,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Dataset_original/movies_dataset_arreglado_1.csv",delimiter=";")

# %% [markdown]
# Litle description of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45462 entries, 0 to 45461
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45462 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45462 non-null  int64
#  3   genres                 45462 non-null  object
#  4   homepage               7778 non-null   object
#  5   id                     45462 non-null  int64
#  6   imdb_id                45445 non-null  object
#  7   original_language      45451 non-null  object
#  8   original_title         45462 non-null  object
#  9   overview               44508 non-null  object
#  10  popularity             45462 non-null  object
#  11  poster_path            45079 non-null  object
#  12  production_companies   45462 non-null  object
#  13  production_countries   45462 non-null  object
# ...

# %% [markdown]
# First task: Remove columns that will not be used, video,imdb_id,adult,original_title,vote_count,poster_path and homepage.

# %%
df.drop(["video","imdb_id","adult","original_title","vote_count","poster_path", "homepage"],axis=1,inplace=True)

# %% [markdown]
# Second task: The null values ​​of the fields revenue, budget must be filled with the number 0

# %%
df.budget.fillna(0,inplace=True)
df.revenue.fillna(0, inplace=True)

# %% [markdown]
# Third task: The null values from release_date field must be deleted.

# %%
df.dropna(subset=['release_date'],inplace=True)
df.reset_index(drop=True)
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45456                                                NaN         0
# 45458                                                NaN         0
# 45459                                                NaN         0
# 45460                                                NaN         0
# 45461                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# Third task :If there are dates, they must have the format YYYY-mm-dd, and it must also create the release_year column where they will extract the year of the release date.

# %%
df.release_date=pd.to_datetime(df['release_date'], format='%Y-%m-%d', errors='coerce')

# %%
df["release_year"]=df.release_date.dt.year
df.reset_index(drop=True,inplace=True)
df.dropna(subset=['release_date'], inplace=True)
df['release_year'] = df['release_year'].astype(int, errors = 'raise')

# %% [markdown]
# Fourth task: The null values from release_date field must be deleted.

# %%
df.dropna(subset=['release_date'], inplace=True)
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# Fifth task: Create the column with the return on investment, called return with the revenue and budget fields, dividing these last two revenue / budget, when there is no data available to calculate it, it must take the value 0.

# %%
df['revenue'] = df['revenue'].astype(float, errors = 'raise')
df['budget'] = df['budget'].astype(float, errors='raise')

# %%
df["return"]=df.revenue.div(df.budget.replace(0,np.nan)).fillna(0)

# %%
df
# Out:
#                                    belongs_to_collection      budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                    NaN  65000000.0
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                    NaN  16000000.0
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...                                                  ...         ...
# 45372                                                NaN         0.0
# 45373                                                NaN         0.0
# 45374                                                NaN         0.0
# 45375                                                NaN         0.0
# 45376                                                NaN         0.0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# Sixth Task:Some fields, like belongs_to_collection, production_companies and others (see data dictionary) are nested, that is, they either have a dictionary or a list as values ​​in each row, you will need to un-nest them to be able to join the dataset again to do any of the queries! from the API! Or find a way to access that data without un-nested.

# %% [markdown]
# Belongs_to_collection => Dictionary

# %%
def convert_diccionario(diccionario):
    if isinstance(diccionario,str) and "{" in diccionario:
        dic=ast.literal_eval(diccionario)
        return dic["name"]

# %%
df["belongs_to_collection"]=df["belongs_to_collection"].apply(convert_diccionario)

# %% [markdown]
# Production_companies => List

# %%
def convert_lista(lista):
    if isinstance(lista, str) and "{" in lista:
        L=[]
        for i in ast.literal_eval(lista):
            L.append(i["name"])
        return L

# %%
df["production_companies"]=df["production_companies"].apply(convert_lista)

# %%
df["genres"]=df["genres"].apply(convert_lista)
df["production_countries"]=df["production_countries"].apply(convert_lista)
##df["spoken_languages"]=df["spoken_languages"].apply(convert_lista)

# %%
df
# Out:
#                 belongs_to_collection      budget  \
# 0                Toy Story Collection  30000000.0
# 1                                None  65000000.0
# 2           Grumpy Old Men Collection         0.0
# 3                                None  16000000.0
# 4      Father of the Bride Collection         0.0
# ...                               ...         ...
# 45372                            None         0.0
# 45373                            None         0.0
# 45374                            None         0.0
# 45375                            None         0.0
# 45376                            None         0.0
#
#                              genres      id original_language  \
# 0       [Animation, Comedy, Family]     862                en
# 1      [Adventure, Fantasy, Family]    8844                en
# 2                 [Romance, Comedy]   15602                en
# 3          [Comedy, Drama, Romance]   31357                en
# ...

# %% [markdown]
# Export Dataset

# %%
df.to_csv("dataset_API1.csv")

# %%
for i in range(df.shape[0]):
    try:
        df.genres.iloc[i]=",".join(df.genres.iloc[i])
    except:
        df.genres.iloc[i]=np.nan
# Out:
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\2424366865.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.genres.iloc[i]=",".join(df.genres.iloc[i])
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\2424366865.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.genres.iloc[i]=np.nan

# %%
af1=dfffff.genres.str.split(',',expand=True)

# %%
af1[0][af1[0]=="Animation"]
# Out:
# 0        Animation
# 309      Animation
# 387      Animation
# 581      Animation
# 589      Animation
#            ...
# 45305    Animation
# 45367    Animation
# 45382    Animation
# 45384    Animation
# 45445    Animation
# Name: 0, Length: 1124, dtype: object

# %%
af2=af1[0][(af1[0]=="Animation") | (af1[1]=="Animation") | (af1[2]=="Animation") | (af1[3]=="Animation") | (af1[4]=="Animation") | (af1[5]=="Animation") | (af1[6]=="Animation") | (af1[7]=="Animation")]

# %%
af2
# Out:
# 0        Animation
# 12          Family
# 47       Adventure
# 235        Romance
# 240        Fantasy
#            ...
# 45367    Animation
# 45382    Animation
# 45384    Animation
# 45433       Family
# 45445    Animation
# Name: 0, Length: 1935, dtype: object

# %%
df4=df.belongs_to_collection[0]
    
res=json.loads(df4)
df5 = pd.DataFrame([res])
df2=df.belongs_to_collection[2]
    
res1=json.loads(df2)
df6 = pd.DataFrame([res1])




df5.merge(df6,how="inner",on="id")
# Out:
# Empty DataFrame
# Columns: [id, name_x, poster_path_x, backdrop_path_x, name_y, poster_path_y, backdrop_path_y]
# Index: []

# %%
df.belongs_to_collection.astype(str)
# Out:
# 0        {"id": 10194, "name": "Toy Story Collection", ...
# 1                                                      nan
# 2        {"id": 119050, "name": "Grumpy Old Men Collect...
# 3                                                      nan
# 4        {"id": 96871, "name": "Father of the Bride Col...
#                                ...
# 45457                                                  nan
# 45458                                                  nan
# 45459                                                  nan
# 45460                                                  nan
# 45461                                                  nan
# Name: belongs_to_collection, Length: 45462, dtype: object

# %%
import json
dff=pd.DataFrame()
for i in range(df.shape[0]):
    
    df4=df.belongs_to_collection[i]
    try :
        res=json.loads(df4)
        
    except Exception:
        res={}
    df5 =pd.DataFrame([res])
    dff=pd.concat([dff,df5])

dff.reset_index()
# Out:
#        index        id                            name  \
# 0          0   10194.0            Toy Story Collection
# 1          0       NaN                             NaN
# 2          0  119050.0       Grumpy Old Men Collection
# 3          0       NaN                             NaN
# 4          0   96871.0  Father of the Bride Collection
# ...      ...       ...                             ...
# 45457      0       NaN                             NaN
# 45458      0       NaN                             NaN
# 45459      0       NaN                             NaN
# 45460      0       NaN                             NaN
# 45461      0       NaN                             NaN
#
#                             poster_path                     backdrop_path
# 0      /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                                   NaN                               NaN
# 2      /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# ...

# %%
df.belongs_to_collection.iloc[75]=df.belongs_to_collection.iloc[75].replace("None", '"Nada"')
# Out:
# C:\Users\angeo\AppData\Local\Temp\ipykernel_10744\4092362286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.belongs_to_collection.iloc[75]=df.belongs_to_collection.iloc[75].replace("None", '"Nada"')

# %%
df4=df.belongs_to_collection[0]
if df4:    
    res=json.loads(df4)
    pass
else:
    res={}
df5 =pd.DataFrame([res])
df5
# Out:
#       id                  name                       poster_path  \
# 0  10194  Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
#
#                       backdrop_path
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg

# %%
df5=df.genres[0]

for i in range(len(df5)):
    if df5[i]:
        res=json.loads(df5[i])
        pass
    else:
        res={}
    df7=pd.DateFrame([df5[i]])
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df5=df.genres[0]
#       3 for i in range(len(df5)):
#       4     if df5[i]:
#
# NameError: name 'df' is not defined

# %%
df.production_countries.iloc[150]
a = df.production_countries.iloc[150].split('},')
dff=pd.DataFrame()
dfff=pd.DataFrame()
for i in range(len(a)):
    try:
        res = json.loads(a[i])
    except Exception:
        res = {}
    df5 = pd.DataFrame([res])
    dff = pd.concat([dff, df5])
    dfff=dfff.join(df5)
dff.reset_index()
dfff
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 12
#      10     df5 = pd.DataFrame([res])
#      11     dff = pd.concat([dff, df5])
# ---> 12     dfff=dfff.join(df5)
#      13 dff.reset_index()
#      14 dfff
#
# File c:\Users\angeo\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:9976, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9813 def join(
#    9814     self,
#    9815     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9821     validate: str | None = None,
#    9822 ) -> DataFrame:
#    9823     """
#    9824     Join columns of another DataFrame.
#    9825
#    (...)
#    9974     5  K1  A5   B1
#    9975     """
# -> 9976     return self._join_compat(
#    9977         other,
#    9978         on=on,
#    9979         how=how,
#    9980         lsuffix=lsuffix,
# ...

# %%
df.production_countries=df.production_countries.str.replace("\'", "\"")
df.production_countries=df.production_countries.str.replace("\[", "")
df.production_countries=df.production_countries.str.replace("\]", "")
df.production_countries=df.production_countries.str.replace("},","}},")
# Out:
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\3347774923.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.production_countries=df.production_countries.str.replace("\[", "")
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\3347774923.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.production_countries=df.production_countries.str.replace("\]", "")
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\3347774923.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.production_countries=df.production_countries.str.replace("},","}},")

# %%
df.production_countries=df.production_countries.str.replace("},","}},")
# Out:
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\172449127.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.genres=df.genres.str.replace("},","}},")

# %%
df.genres.iloc[0]
a=df.genres.iloc[0].split('},')

# %%
df.genres=df.genres.str.replace("\'", "\"")
df.genres=df.genres.str.replace("\[", "")
df.genres=df.genres.str.replace("\]", "")
# Out:
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\1482484019.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.genres=df.genres.str.replace("\[", "")
# C:\Users\angeo\AppData\Local\Temp\ipykernel_6080\1482484019.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.genres=df.genres.str.replace("\]", "")

# %%
df.belongs_to_collection.fillna("",inplace=True)

# %%
df.belongs_to_collection=df.belongs_to_collection.str.replace("\'", "\"")
